# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sklearn.neighbors
import sys
sys.path.append('C:/Users/petera/Documents/Envirodual/paths')
sys.path.append('C:/Users/petera/Documents/Envirodual/values')
sys.path.append('C:/Users/petera/Documents/Envirodual/utils')
from path_definition import all_cities, city_paths, model
from preprocessing import one_hot_encode_column, decode_column
from values import OB_MID_dict, area_use_codes, area_use_columns, heated_area_codes
import warnings
warnings.filterwarnings('ignore')

# %%
city_name = 'ljubljana'
OB_MID = OB_MID_dict[city_name]
paths = city_paths[city_name]

# %% [markdown]
# ## Read REN data

# %%
# columns to load from tables
cols_stavbe = ['STA_SID',
               'OB_MID',
               'ST_ETAZ',
               'ST_PRIT_ETAZE',
               'ST_STANOVANJ',
               'ST_POSLOVNIH_PROSTOROV',
               'DEJANSKA_RABA',
               'ID_TIP_STAVBE',
               'LETO_IZG_STA',
               'LETO_OBN_STREHE',
               'LETO_OBN_FASADE',
               'ID_KONSTRUKCIJE',
               'ID_OGREVANJE']

# %%
# read stavbe
stavbe_path = all_cities['root'] / all_cities['stavbe']
stavbe = pd.read_csv(
    stavbe_path,
    usecols=cols_stavbe,
    index_col='STA_SID',
    # encoding='cp1250',
    sep=';'
)

# keep only current municipality
stavbe = stavbe[stavbe.OB_MID.eq(OB_MID)]

# %%
cols_delistavb = ['STA_SID',
                  'DEJANSKA_RABA',
                  'UPOR_POV_STAN',
                  'NETO_TLORIS_POV_DST',
                  'LETO_OBN_OKEN',
                  'ID_POCIT_RABA']

# read delistavb
delistavb_path = all_cities['root'] / all_cities['delistavb']
delistavb = pd.read_csv(
    delistavb_path,
    usecols=cols_delistavb,
    # encoding='cp1250',
    decimal=',',
    sep=';'
)
delistavb = delistavb[delistavb.STA_SID.isin(stavbe.index.unique())]

# %%
# read sifranti
sifranti_path = all_cities['root'] / all_cities['sifranti']
sifranti = pd.read_csv(
    sifranti_path,
    # encoding='cp1250',
    sep=';'
)

# %% [markdown]
# # Temperature deficit

# %%
file_path_temp_deficit = all_cities['root'] / all_cities['temperature_deficit_cleaned']
temp_deficit = pd.read_csv(
    file_path_temp_deficit,
    index_col='STA_SID',
    usecols=['TEMP_DEFICIT','STA_SID']
)

# %% [markdown]
# # Read gas data

# %%
dtype = {'ZP': 'int', 'STA_SID': 'int'}
file_path_gas = all_cities['root'] / paths['gas_cleaned']
gas = pd.read_csv(
    file_path_gas,
    usecols=['ZP', 'STA_SID'],
    dtype=dtype,
    index_col='STA_SID'
)

# %%
df = gas.join(stavbe, how='inner').join(temp_deficit, how='left')

# %%
gas.shape, df.shape
# Out:
# ((1958, 1), (1957, 14))

# %% [markdown]
# # Missing data REN

# %%
# drop entries where areas m2 not given
delistavb.fillna(0, inplace=True)

# %%
# collect total areas of building
df['UPORABNA_POVRSINA'] = delistavb.groupby('STA_SID')['UPOR_POV_STAN'].sum()
df['NETO_TLORIS'] = delistavb.groupby('STA_SID')['NETO_TLORIS_POV_DST'].sum()

# %%
# drop nans
df.dropna(subset=['UPORABNA_POVRSINA', 'NETO_TLORIS'], inplace=True)

# %%
# MISSING DATA
all_data_na = (df.isnull().sum() / len(df)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(20)
# Out:
#                  Missing Ratio
# LETO_OBN_FASADE      71.640266
# LETO_OBN_STREHE      51.047522
# TEMP_DEFICIT         15.125192
# ID_TIP_STAVBE         0.306592
# ST_PRIT_ETAZE         0.306592
# ID_OGREVANJE          0.204394
# ST_ETAZ               0.204394
# ID_KONSTRUKCIJE       0.153296
# LETO_IZG_STA          0.102197
# DEJANSKA_RABA         0.102197

# %%
# get mean windows age
df['LETO_OBN_OKEN'] = delistavb.groupby('STA_SID')['LETO_OBN_OKEN'].median().astype(int)

# %%
def fill_and_mark(df, column, value=0):
    '''fills missing values and creates new column marking which entries have been filled'''
    df_ = df.copy()
    df_['NA_'+column] = 0
    idx = df_[df_[column].isna()].index.astype('int32')
    df_.loc[idx,'NA_'+column] = 1
    df_[column].fillna(value, inplace=True)
    return df_

# %%
# If building rennovation year not given, set rennovation to construction year
v = df['LETO_IZG_STA'].median()

df = fill_and_mark(df, 'LETO_IZG_STA', v)
#df = fill_and_mark(df, 'LETO_OBN_OKEN', v)
#df = fill_and_mark(df, 'LETO_OBN_STREHE', v)
#df = fill_and_mark(df, 'LETO_OBN_FASADE', v)

# %%
for c in ['LETO_OBN_OKEN', 'LETO_OBN_STREHE', 'LETO_OBN_FASADE']:
    df['NA_'+c] = 0
    idx = (df[c].isna()) | (df[c]==0)
    df.loc[idx,'NA_'+c] = 1
    df.loc[idx, c] = df.loc[idx]['LETO_IZG_STA']

# %%
for c in ['ID_TIP_STAVBE', 'ID_OGREVANJE', 'ID_KONSTRUKCIJE', 'DEJANSKA_RABA', 'TEMP_DEFICIT']:
    v = df[c].median()
    df = fill_and_mark(df, c, v)

# %%
# Impute remaining missing values
def imputer_kNeighbors(df, attrib_to_impute, reference, n_neighbors=3):

    neigh = sklearn.neighbors.KNeighborsRegressor(n_neighbors=n_neighbors)

    y = df[df[attrib_to_impute] > 0][attrib_to_impute]
    x = df[df[attrib_to_impute] > 0][reference].values.reshape(-1, 1)

    neigh.fit(x, y)

    x_missing = df[df[attrib_to_impute].isna()][reference].values.reshape(-1, 1)
    imputed_values = neigh.predict(x_missing)
    # df.loc[df['attrib_to_impute'].isna(), 'attrib_to_impute'] = imputed_values
    return imputed_values

# %%
df.loc[df['ST_ETAZ'].isna(), 'ST_ETAZ'] = (
    imputer_kNeighbors(df, attrib_to_impute='ST_ETAZ', reference='NETO_TLORIS', n_neighbors=3)
)

df.loc[df['ST_PRIT_ETAZE'].isna(), 'ST_PRIT_ETAZE'] = (
    imputer_kNeighbors(df, attrib_to_impute='ST_PRIT_ETAZE', reference='NETO_TLORIS', n_neighbors=3)
)

# %%
all_data_na = (df.isnull().sum() / len(df)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(20)
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %% [markdown]
# ## Engineer new variables

# %%
# add variable to represent the share of the area dedicated to second holiday houses/apartments
df['SHARE_HOLIDAY'] = delistavb[delistavb['ID_POCIT_RABA'] == 1622].groupby('STA_SID')['UPOR_POV_STAN'].sum()
df['SHARE_HOLIDAY'] = df['SHARE_HOLIDAY'] / df['UPORABNA_POVRSINA']
df['SHARE_HOLIDAY'].fillna(0, inplace=True)

# %%
columns_one_hot_encode = ['ID_TIP_STAVBE',
                          'DEJANSKA_RABA',
                          'ID_KONSTRUKCIJE',
                          'ID_OGREVANJE']

# decode columns
for col in columns_one_hot_encode:
    codes = df[col].unique()
    categories = sifranti.loc[sifranti.ID.isin(codes)]['IME'].values
    d = dict(zip(codes, categories))
    df = decode_column(df, col, d)

for c in columns_one_hot_encode:
    df = one_hot_encode_column(df, column=c)

# %% [markdown]
# # Create area use variables

# %%
area_use_cols = sifranti.loc[sifranti.POLJE_PK == 'DEJANSKA_RABA']['IME']
for c in area_use_cols:
    df[c] = 0

# %%
#areas_use = sifranti.loc[sifranti.POLJE_PK == 'DEJANSKA_RABA'][['ID', 'IME']]

# drop STA_SID that are not in the final table
delistavb = delistavb[delistavb.STA_SID.isin(df.index)]

# %%
for r, c in zip(area_use_codes, area_use_columns):
    tmp = delistavb.loc[delistavb.DEJANSKA_RABA == r][['STA_SID', 'UPOR_POV_STAN']]
    tmp = tmp.groupby('STA_SID')['UPOR_POV_STAN'].sum()
    df.loc[tmp.index, c] = tmp.values

# %%
# sum up heated area
ds = delistavb.loc[delistavb.DEJANSKA_RABA.isin(heated_area_codes)]
df['HEATED_AREA'] = ds.groupby('STA_SID')['UPOR_POV_STAN'].sum()
df.HEATED_AREA.fillna(0, inplace=True)

# %% [markdown]
# # Save result

# %%
all_data_na = (df.isnull().sum() / len(df)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(20)
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
file_path = all_cities['root'] / model['gas_' + city_name]
df.to_csv(
    file_path,
)

# %%
d = df['ZP']/df['UPORABNA_POVRSINA']

# %%
d[(d>5) & (d<1300)].mean() # Ljubljana 158.64 kWh
# Out:
# 131.46343655939418

# %%
df.UPORABNA_POVRSINA.sum() # 7 752 556.6
# Out:
# 708843.6

# %%
df.head(10).T
# Out:
# STA_SID                                               21638312    21768485  \
# ZP                                                     95012.0     40660.0
# OB_MID                                              11027784.0  11027784.0
# ST_ETAZ                                                    7.0         7.0
# ST_PRIT_ETAZE                                              2.0         1.0
# ST_STANOVANJ                                              20.0        16.0
# ST_POSLOVNIH_PROSTOROV                                     0.0         0.0
# LETO_IZG_STA                                            1964.0      1961.0
# LETO_OBN_STREHE                                         1964.0      2003.0
# LETO_OBN_FASADE                                         1964.0      1961.0
# TEMP_DEFICIT                                            3500.0      3500.0
# UPORABNA_POVRSINA                                       1208.9       705.3
# NETO_TLORIS                                             1761.1      1008.4
# LETO_OBN_OKEN                                           1964.0      1999.0
# NA_LETO_IZG_STA                                            0.0         0.0
# NA_LETO_OBN_OKEN                                           1.0         0.0
# NA_LETO_OBN_STREHE                                         1.0         0.0
# NA_LETO_OBN_FASADE                                         1.0         1.0
# NA_ID_TIP_STAVBE                                           0.0         0.0
# NA_ID_OGREVANJE                                            0.0         0.0
# NA_ID_KONSTRUKCIJE                                         0.0         0.0
# NA_DEJANSKA_RABA                                           0.0         0.0
# NA_TEMP_DEFICIT                                            0.0         1.0
# SHARE_HOLIDAY                                              0.0         0.0
# ID_TIP_STAVBE_0                                            1.0         0.0
# ID_TIP_STAVBE_1                                            0.0         1.0
# ID_TIP_STAVBE_2                                            0.0         0.0
# ID_TIP_STAVBE_3                                            0.0         0.0
# DEJANSKA_RABA_0                                            1.0         1.0
# DEJANSKA_RABA_1                                            0.0         0.0
# ID_KONSTRUKCIJE_0                                          1.0         0.0
# ...                                                        ...         ...
# Garaža                                                     0.0         0.0
# Garažno parkirno mesto                                     0.0         0.0
# Del stavbe za industrijsko rabo                            0.0         0.0
# Del stavbe za težko industrijo                             0.0         0.0
# Del stavbe z rezervoarjem, silos                           0.0         0.0
# Skladišče                                                  0.0         0.0
# Del stavbe za kulturo in razvedrilo                        0.0         0.0
# Muzej in knjižnica                                         0.0         0.0
# Del stavbe za izobraževanje in znanstveno razis...         0.0         0.0
# Del stavbe za zdravstveno oskrbo                           0.0         0.0
# Pomožni kmetijski del stavbe                               0.0         0.0
# Del stavbe za spravilo pridelka                            0.0         0.0
# Del stavbe za opravljanje verskih obredov                  0.0         0.0
# Del stavbe za pokopališko dejavnost                        0.0         0.0
# Del stavbe za zaščito, reševanje in zaklonišče             0.0         0.0
# Shramba, sušilnica, pralnica                               0.0         0.0
# Terasa, balkon, loža                                       0.0         0.0
# Tehnični prostor                                           0.0         0.0
# Skupni komunikacijski prostor                              0.0         0.0
# Skupne sanitarije                                          0.0         0.0
# Del stavbe za posebne namene                               0.0         0.0
# Bolnica, zdravstveni dom                                   0.0         0.0
# Del stavbe za pastoralno dejavnost                         0.0         0.0
# Stanovanje v dvostanovanjski stavbi                        0.0         0.0
# Konferenčna ali kongresna dvorana                          0.0         0.0
# Trgovski del stavbe na bencinskih servisih                 0.0         0.0
# Igralnica, cirkus, plesna dvorana, diskoteka               0.0         0.0
# Hangar, remiza, tovorni terminal                           0.0         0.0
# Del stavbe za živali ali rastline v živalskem a...         0.0         0.0
# HEATED_AREA                                             1208.9       705.3
#
# STA_SID                                               21768486    21779520  \
# ZP                                                     40766.0     98996.0
# OB_MID                                              11027784.0  11027784.0
# ST_ETAZ                                                    7.0         7.0
# ST_PRIT_ETAZE                                              1.0         2.0
# ST_STANOVANJ                                              15.0        21.0
# ST_POSLOVNIH_PROSTOROV                                     0.0         0.0
# LETO_IZG_STA                                            1961.0      1964.0
# LETO_OBN_STREHE                                         2003.0      1964.0
# LETO_OBN_FASADE                                         1961.0      1964.0
# TEMP_DEFICIT                                            3500.0      3500.0
# UPORABNA_POVRSINA                                        694.2      1090.3
# NETO_TLORIS                                             1003.5      1194.4
# LETO_OBN_OKEN                                           1961.0      1964.0
# NA_LETO_IZG_STA                                            0.0         0.0
# NA_LETO_OBN_OKEN                                           1.0         1.0
# NA_LETO_OBN_STREHE                                         0.0         1.0
# NA_LETO_OBN_FASADE                                         1.0         1.0
# NA_ID_TIP_STAVBE                                           0.0         0.0
# NA_ID_OGREVANJE                                            0.0         0.0
# NA_ID_KONSTRUKCIJE                                         0.0         0.0
# NA_DEJANSKA_RABA                                           0.0         0.0
# NA_TEMP_DEFICIT                                            0.0         1.0
# SHARE_HOLIDAY                                              0.0         0.0
# ID_TIP_STAVBE_0                                            0.0         1.0
# ID_TIP_STAVBE_1                                            1.0         0.0
# ID_TIP_STAVBE_2                                            0.0         0.0
# ID_TIP_STAVBE_3                                            0.0         0.0
# DEJANSKA_RABA_0                                            1.0         1.0
# DEJANSKA_RABA_1                                            0.0         0.0
# ID_KONSTRUKCIJE_0                                          0.0         0.0
# ...                                                        ...         ...
# Garaža                                                     0.0         0.0
# Garažno parkirno mesto                                     0.0         0.0
# Del stavbe za industrijsko rabo                            0.0         0.0
# Del stavbe za težko industrijo                             0.0         0.0
# Del stavbe z rezervoarjem, silos                           0.0         0.0
# Skladišče                                                  0.0         0.0
# Del stavbe za kulturo in razvedrilo                        0.0         0.0
# Muzej in knjižnica                                         0.0         0.0
# Del stavbe za izobraževanje in znanstveno razis...         0.0         0.0
# Del stavbe za zdravstveno oskrbo                           0.0         0.0
# Pomožni kmetijski del stavbe                               0.0         0.0
# Del stavbe za spravilo pridelka                            0.0         0.0
# Del stavbe za opravljanje verskih obredov                  0.0         0.0
# Del stavbe za pokopališko dejavnost                        0.0         0.0
# Del stavbe za zaščito, reševanje in zaklonišče             0.0         0.0
# Shramba, sušilnica, pralnica                               0.0         0.0
# Terasa, balkon, loža                                       0.0         0.0
# Tehnični prostor                                           0.0         0.0
# Skupni komunikacijski prostor                              0.0         0.0
# Skupne sanitarije                                          0.0         0.0
# Del stavbe za posebne namene                               0.0         0.0
# Bolnica, zdravstveni dom                                   0.0         0.0
# Del stavbe za pastoralno dejavnost                         0.0         0.0
# Stanovanje v dvostanovanjski stavbi                        0.0         0.0
# Konferenčna ali kongresna dvorana                          0.0         0.0
# Trgovski del stavbe na bencinskih servisih                 0.0         0.0
# Igralnica, cirkus, plesna dvorana, diskoteka               0.0         0.0
# Hangar, remiza, tovorni terminal                           0.0         0.0
# Del stavbe za živali ali rastline v živalskem a...         0.0         0.0
# HEATED_AREA                                              694.2       958.2
#
# STA_SID                                               21780156    21780175  \
# ZP                                                     81280.0      9776.0
# OB_MID                                              11027784.0  11027784.0
# ST_ETAZ                                                    7.0         5.0
# ST_PRIT_ETAZE                                              2.0         2.0
# ST_STANOVANJ                                              21.0        11.0
# ST_POSLOVNIH_PROSTOROV                                     0.0         1.0
# LETO_IZG_STA                                            1964.0      1962.0
# LETO_OBN_STREHE                                         1964.0      1962.0
# LETO_OBN_FASADE                                         1964.0      1962.0
# TEMP_DEFICIT                                            3500.0      3500.0
# UPORABNA_POVRSINA                                       1325.5       369.4
# NETO_TLORIS                                             1433.6       421.9
# LETO_OBN_OKEN                                           1964.0      1996.0
# NA_LETO_IZG_STA                                            0.0         0.0
# NA_LETO_OBN_OKEN                                           1.0         0.0
# NA_LETO_OBN_STREHE                                         1.0         1.0
# NA_LETO_OBN_FASADE                                         1.0         1.0
# NA_ID_TIP_STAVBE                                           0.0         0.0
# NA_ID_OGREVANJE                                            0.0         0.0
# NA_ID_KONSTRUKCIJE                                         0.0         0.0
# NA_DEJANSKA_RABA                                           0.0         0.0
# NA_TEMP_DEFICIT                                            0.0         0.0
# SHARE_HOLIDAY                                              0.0         0.0
# ID_TIP_STAVBE_0                                            1.0         0.0
# ID_TIP_STAVBE_1                                            0.0         1.0
# ID_TIP_STAVBE_2                                            0.0         0.0
# ID_TIP_STAVBE_3                                            0.0         0.0
# DEJANSKA_RABA_0                                            1.0         1.0
# DEJANSKA_RABA_1                                            0.0         0.0
# ID_KONSTRUKCIJE_0                                          0.0         0.0
# ...                                                        ...         ...
# Garaža                                                     0.0         0.0
# Garažno parkirno mesto                                     0.0         0.0
# Del stavbe za industrijsko rabo                            0.0         0.0
# Del stavbe za težko industrijo                             0.0         0.0
# Del stavbe z rezervoarjem, silos                           0.0         0.0
# Skladišče                                                  0.0         0.0
# Del stavbe za kulturo in razvedrilo                        0.0         0.0
# Muzej in knjižnica                                         0.0         0.0
# Del stavbe za izobraževanje in znanstveno razis...         0.0         0.0
# Del stavbe za zdravstveno oskrbo                           0.0         0.0
# Pomožni kmetijski del stavbe                               0.0         0.0
# Del stavbe za spravilo pridelka                            0.0         0.0
# Del stavbe za opravljanje verskih obredov                  0.0         0.0
# Del stavbe za pokopališko dejavnost                        0.0         0.0
# Del stavbe za zaščito, reševanje in zaklonišče             0.0         0.0
# Shramba, sušilnica, pralnica                               0.0         0.0
# Terasa, balkon, loža                                       0.0         0.0
# Tehnični prostor                                           0.0         0.0
# Skupni komunikacijski prostor                              0.0         0.0
# Skupne sanitarije                                          0.0         0.0
# Del stavbe za posebne namene                               0.0         0.0
# Bolnica, zdravstveni dom                                   0.0         0.0
# Del stavbe za pastoralno dejavnost                         0.0         0.0
# Stanovanje v dvostanovanjski stavbi                        0.0         0.0
# Konferenčna ali kongresna dvorana                          0.0         0.0
# Trgovski del stavbe na bencinskih servisih                 0.0         0.0
# Igralnica, cirkus, plesna dvorana, diskoteka               0.0         0.0
# Hangar, remiza, tovorni terminal                           0.0         0.0
# Del stavbe za živali ali rastline v živalskem a...         0.0         0.0
# HEATED_AREA                                             1205.6       280.2
#
# STA_SID                                               21780176    21825597  \
# ZP                                                     34304.0     98066.0
# OB_MID                                              11027784.0  11027784.0
# ST_ETAZ                                                    4.0         5.0
# ST_PRIT_ETAZE                                              1.0         2.0
# ST_STANOVANJ                                               6.0        21.0
# ST_POSLOVNIH_PROSTOROV                                     0.0         0.0
# LETO_IZG_STA                                            1962.0      1963.0
# LETO_OBN_STREHE                                         1962.0      2002.0
# LETO_OBN_FASADE                                         1962.0      1963.0
# TEMP_DEFICIT                                            3500.0      3500.0
# UPORABNA_POVRSINA                                        278.6      1286.7
# NETO_TLORIS                                              418.8      1394.4
# LETO_OBN_OKEN                                           1999.0      1963.0
# NA_LETO_IZG_STA                                            0.0         0.0
# NA_LETO_OBN_OKEN                                           0.0         1.0
# NA_LETO_OBN_STREHE                                         1.0         0.0
# NA_LETO_OBN_FASADE                                         1.0         1.0
# NA_ID_TIP_STAVBE                                           0.0         0.0
# NA_ID_OGREVANJE                                            0.0         0.0
# NA_ID_KONSTRUKCIJE                                         0.0         0.0
# NA_DEJANSKA_RABA                                           0.0         0.0
# NA_TEMP_DEFICIT                                            0.0         0.0
# SHARE_HOLIDAY                                              0.0         0.0
# ID_TIP_STAVBE_0                                            0.0         1.0
# ID_TIP_STAVBE_1                                            0.0         0.0
# ID_TIP_STAVBE_2                                            1.0         0.0
# ID_TIP_STAVBE_3                                            0.0         0.0
# DEJANSKA_RABA_0                                            1.0         1.0
# DEJANSKA_RABA_1                                            0.0         0.0
# ID_KONSTRUKCIJE_0                                          0.0         0.0
# ...                                                        ...         ...
# Garaža                                                     0.0         0.0
# Garažno parkirno mesto                                     0.0         0.0
# Del stavbe za industrijsko rabo                            0.0         0.0
# Del stavbe za težko industrijo                             0.0         0.0
# Del stavbe z rezervoarjem, silos                           0.0         0.0
# Skladišče                                                  0.0         0.0
# Del stavbe za kulturo in razvedrilo                        0.0         0.0
# Muzej in knjižnica                                         0.0         0.0
# Del stavbe za izobraževanje in znanstveno razis...         0.0         0.0
# Del stavbe za zdravstveno oskrbo                           0.0         0.0
# Pomožni kmetijski del stavbe                               0.0         0.0
# Del stavbe za spravilo pridelka                            0.0         0.0
# Del stavbe za opravljanje verskih obredov                  0.0         0.0
# Del stavbe za pokopališko dejavnost                        0.0         0.0
# Del stavbe za zaščito, reševanje in zaklonišče             0.0         0.0
# Shramba, sušilnica, pralnica                               0.0         0.0
# Terasa, balkon, loža                                       0.0         0.0
# Tehnični prostor                                           0.0         0.0
# Skupni komunikacijski prostor                              0.0         0.0
# Skupne sanitarije                                          0.0         0.0
# Del stavbe za posebne namene                               0.0         0.0
# Bolnica, zdravstveni dom                                   0.0         0.0
# Del stavbe za pastoralno dejavnost                         0.0         0.0
# Stanovanje v dvostanovanjski stavbi                        0.0         0.0
# Konferenčna ali kongresna dvorana                          0.0         0.0
# Trgovski del stavbe na bencinskih servisih                 0.0         0.0
# Igralnica, cirkus, plesna dvorana, diskoteka               0.0         0.0
# Hangar, remiza, tovorni terminal                           0.0         0.0
# Del stavbe za živali ali rastline v živalskem a...         0.0         0.0
# HEATED_AREA                                              278.6      1173.2
#
# STA_SID                                               21825626    21827672
# ZP                                                     70573.0     14168.0
# OB_MID                                              11027784.0  11027784.0
# ST_ETAZ                                                    5.0         4.0
# ST_PRIT_ETAZE                                              2.0         2.0
# ST_STANOVANJ                                              10.0         4.0
# ST_POSLOVNIH_PROSTOROV                                     0.0         0.0
# LETO_IZG_STA                                            1958.0      1954.0
# LETO_OBN_STREHE                                         1958.0      1954.0
# LETO_OBN_FASADE                                         1958.0      1954.0
# TEMP_DEFICIT                                            3500.0      3500.0
# UPORABNA_POVRSINA                                        591.3       610.2
# NETO_TLORIS                                              898.7       749.1
# LETO_OBN_OKEN                                           1958.0      1954.0
# NA_LETO_IZG_STA                                            0.0         0.0
# NA_LETO_OBN_OKEN                                           1.0         1.0
# NA_LETO_OBN_STREHE                                         1.0         1.0
# NA_LETO_OBN_FASADE                                         1.0         1.0
# NA_ID_TIP_STAVBE                                           0.0         0.0
# NA_ID_OGREVANJE                                            0.0         0.0
# NA_ID_KONSTRUKCIJE                                         0.0         0.0
# NA_DEJANSKA_RABA                                           0.0         0.0
# NA_TEMP_DEFICIT                                            0.0         0.0
# SHARE_HOLIDAY                                              0.0         0.0
# ID_TIP_STAVBE_0                                            1.0         0.0
# ID_TIP_STAVBE_1                                            0.0         0.0
# ID_TIP_STAVBE_2                                            0.0         1.0
# ID_TIP_STAVBE_3                                            0.0         0.0
# DEJANSKA_RABA_0                                            1.0         1.0
# DEJANSKA_RABA_1                                            0.0         0.0
# ID_KONSTRUKCIJE_0                                          0.0         0.0
# ...                                                        ...         ...
# Garaža                                                     0.0         0.0
# Garažno parkirno mesto                                     0.0         0.0
# Del stavbe za industrijsko rabo                            0.0         0.0
# Del stavbe za težko industrijo                             0.0         0.0
# Del stavbe z rezervoarjem, silos                           0.0         0.0
# Skladišče                                                  0.0         0.0
# Del stavbe za kulturo in razvedrilo                        0.0         0.0
# Muzej in knjižnica                                         0.0         0.0
# Del stavbe za izobraževanje in znanstveno razis...         0.0         0.0
# Del stavbe za zdravstveno oskrbo                           0.0         0.0
# Pomožni kmetijski del stavbe                               0.0         0.0
# Del stavbe za spravilo pridelka                            0.0         0.0
# Del stavbe za opravljanje verskih obredov                  0.0         0.0
# Del stavbe za pokopališko dejavnost                        0.0         0.0
# Del stavbe za zaščito, reševanje in zaklonišče             0.0         0.0
# Shramba, sušilnica, pralnica                               0.0         0.0
# Terasa, balkon, loža                                       0.0         0.0
# Tehnični prostor                                           0.0         0.0
# Skupni komunikacijski prostor                              0.0         0.0
# Skupne sanitarije                                          0.0         0.0
# Del stavbe za posebne namene                               0.0         0.0
# Bolnica, zdravstveni dom                                   0.0         0.0
# Del stavbe za pastoralno dejavnost                         0.0         0.0
# Stanovanje v dvostanovanjski stavbi                        0.0         0.0
# Konferenčna ali kongresna dvorana                          0.0         0.0
# Trgovski del stavbe na bencinskih servisih                 0.0         0.0
# Igralnica, cirkus, plesna dvorana, diskoteka               0.0         0.0
# Hangar, remiza, tovorni terminal                           0.0         0.0
# Del stavbe za živali ali rastline v živalskem a...         0.0         0.0
# HEATED_AREA                                              591.3       342.0
#
# [214 rows x 10 columns]
